# %%
import numpy as np
import matplotlib.pyplot as plt
import lightkurve as lk
import pandas as pd
import matplotlib.tri as tri


def plot_spectrum(s):
    f = np.fft.rfftfreq(len(s))
    plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
    plt.xlabel("Timescale in days") ## for 1/f
    plt.ylabel("Power Coefficient")
#1/f * 0.02083337081285208
def noise_psd(N, psd = lambda f: 1):
        X_white = np.fft.rfft(np.random.randn(N)); 
        S = psd(np.fft.rfftfreq(N))
        S = S / np.sqrt(np.mean(S**2))
        X_shaped = X_white * S;
        return np.fft.irfft(X_shaped);

def PSDGenerator(f):
    return lambda N: noise_psd(N, f)

@PSDGenerator
def white_noise(f):
    return 1;

@PSDGenerator
def pink_noise(f):
    return 1/np.where(f == 0, float('inf'), np.sqrt(f))


pink_noise=pink_noise(2**10)
white_noise=white_noise(2**14)
white_noise=[point * 0.004092449222912115 + 1 for point in white_noise] #adjusting for error

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 261136679', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013888694722936634
# Tess data len:  18279
# Standard dev:  0.00012410610390559585

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 422610504', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013889178555928083
# Tess data len:  13865
# Standard dev:  0.004795975899062851

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 616545501', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013889325205127534
# Tess data len:  14759
# Standard dev:  0.01066939307054982

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 34798833', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.002777846819071783
# Tess data len:  16781
# Standard dev:  0.00457705209817954

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 99734568', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.001388916482028435
# Tess data len:  17048
# Standard dev:  0.004392124479805677

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 229879718', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013888933929138148
# Tess data len:  16381
# Standard dev:  0.002323650265283883

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 229881049', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013888896676235163
# Tess data len:  18217
# Standard dev:  0.004595474696828989

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 233188453', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# Warning: 28% (5221/18654) of the cadences will be ignored due to the quality mask (quality_bitmask=7407).
# Warning: 29% (5213/17981) of the cadences will be ignored due to the quality mask (quality_bitmask=7407).
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013888696703361347
# Tess data len:  13433
# Standard dev:  0.00325725344785073

# %%
#normalized tesscurve
ttv = lk.search_lightcurve('TIC 37243198', cadence = "short").download_all(quality_bitmask='hard')
lc=ttv[0].flatten().to_pandas()
lc.reset_index(inplace=True)
flux= lc["flux"]
time = lc["time"] #time starts at >1000

#make time start at 0
time_start_0 = [value - time[0] for value in time]

#plotting lightcurve
plt.scatter(time_start_0,flux, s = 5)
plt.show()

#plotting spectrum
plot_spectrum(flux) #plot as a line 1/frequencies # blue
cadence = time[1]-time[0]

print("cadence in days: " , cadence)
print("Tess data len: " , len(flux))
print("Standard dev: " , np.std(flux))
# Out:
# <ipython-input-2-e70d3ee4d3eb>:10: RuntimeWarning: divide by zero encountered in true_divide
#   plt.loglog(1/f * .0013888694722936634, np.abs(np.fft.rfft(s)),'.') #mult times cadence
# cadence in days:  0.0013889246363305574
# Tess data len:  14691
# Standard dev:  0.004723036186741436
